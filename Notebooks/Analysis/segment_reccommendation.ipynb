# %% [markdown]
# # SQL Results - Segment recommendation

# %% [markdown]
# ## 1.0 Import necessary libraries

# %%
# Data analysis
import pandas as pd

# Directory
from pathlib import Path

# %%
## 2.0 Paths setup

# %%
# Current directory
CURRENT_DIR = Path.cwd()

# Path to main folder
PROJECT_ROOT = CURRENT_DIR.parent.parent

# Path to folders
RESULTS_FOLDER = PROJECT_ROOT/"SQL_results"
RECOMMENDATIONS_RESULTS = RESULTS_FOLDER/"segments_recommendation"

# %% [markdown]
# ## 3.0 Segments recommendation

# %% [markdown]
# ### 3.1 Recommendation per segment

# %%
# Set column width
pd.set_option('display.max_colwidth', 70)

recommendation_per_segment = pd.read_csv(RECOMMENDATIONS_RESULTS/"recommendation_per_segment.csv")

recommendation_per_segment.style.set_properties(**{'text-align': 'left'})
# Out:
# <style type="text/css">
# #T_3308f_row0_col0, #T_3308f_row0_col1, #T_3308f_row0_col2, #T_3308f_row0_col3, #T_3308f_row1_col0, #T_3308f_row1_col1, #T_3308f_row1_col2, #T_3308f_row1_col3, #T_3308f_row2_col0, #T_3308f_row2_col1, #T_3308f_row2_col2, #T_3308f_row2_col3, #T_3308f_row3_col0, #T_3308f_row3_col1, #T_3308f_row3_col2, #T_3308f_row3_col3, #T_3308f_row4_col0, #T_3308f_row4_col1, #T_3308f_row4_col2, #T_3308f_row4_col3, #T_3308f_row5_col0, #T_3308f_row5_col1, #T_3308f_row5_col2, #T_3308f_row5_col3, #T_3308f_row6_col0, #T_3308f_row6_col1, #T_3308f_row6_col2, #T_3308f_row6_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_3308f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3308f_level0_col0" class="col_heading level0 col0" >CustomerSegment</th>
#       <th id="T_3308f_level0_col1" class="col_heading level0 col1" >TotalRevenue</th>
#       <th id="T_3308f_level0_col2" class="col_heading level0 col2" >RevenuePercentage</th>
# ...
